# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
#import matplotlib.font_manager as fm
#%matplotlib inline
# %matplotlib notebook
mpl.rcParams['axes.unicode_minus'] = False
import seaborn as sns

#from IPython.display import Image
#import random as r
#from numpy import NaN, NAN, nan

plt.rcParams['font.size'] = 15
plt.rcParams['font.family'] = 'NanumGothicCoding'

# %% [markdown]
# ### 앤스콤 4분할 그래프

# %%
anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
anscombe[anscombe['dataset'] == 'I']
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
anscombe[anscombe['dataset'] == 'I'].mean()
# Out:
# x    9.000000
# y    7.500909
# dtype: float64

# %%
anscombe[anscombe['dataset'] == 'II'].mean()
# Out:
# x    9.000000
# y    7.500909
# dtype: float64

# %%
anscombe[anscombe['dataset'] == 'III'].mean()
# Out:
# x    9.0
# y    7.5
# dtype: float64

# %%
# 데이터 그룹별 추출
dataset_1 = anscombe[anscombe['dataset'] == 'I']
dataset_1

plt.plot(dataset_1['x'], dataset_1['y'], 'or')

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

plt.plot(dataset_1['x'], dataset_1['y'], 'or')
plt.plot(dataset_2['x'], dataset_2['y'], 'ob')
plt.plot(dataset_3['x'], dataset_3['y'], 'oy')
plt.plot(dataset_4['x'], dataset_4['y'], 'og')

# %%
fig = plt.figure()
plt.rcParams['figure.figsize'] = (5,3)

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(dataset_1['x'], dataset_1['y'], 'or')
axes2.plot(dataset_2['x'], dataset_2['y'], 'ob')
axes3.plot(dataset_3['x'], dataset_3['y'], 'oy')
axes4.plot(dataset_4['x'], dataset_4['y'], 'og')

axes1.set_title('dataset_1')
axes2.set_title('dataset_2')
axes3.set_title('dataset_3')
axes4.set_title('dataset_4')

fig.suptitle('앤스콤 데이터')
fig.tight_layout() # 그래프의 이름과 숫자가 겹칠 시 사용

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="288">
