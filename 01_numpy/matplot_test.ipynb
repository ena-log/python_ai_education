# %%
#!pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
a = [0., 0.25, 0.5, 0.75, 1.]
print(a)
# Out:
# [0.0, 0.25, 0.5, 0.75, 1.0]

# %%
plt.plot(a)

# %%
plt.plot(a)
plt.show()

# %%
plt.plot(a, 'o')
plt.show()

# %%
plt.plot(a, '^')
plt.show()

# %%
plt.plot(a, 's')
plt.show()

# %%
plt.plot(a, 'rs')
plt.show()
